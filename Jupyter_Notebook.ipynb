# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Yongtao Sun**
# Equipment Maintenance Engineer

# %% [markdown]
# *I am interested in data science because there's a lot of process data in my work. I want to do some Predictive Maintenance work using data science and ML/DL*

# %% [markdown]
# ### calculate summary of list

# %%
example_list = [1, 2, 3, 4, 5, 6]
print(sum(example_list))
# Out:
# 21

# %% [markdown]
# ---
# -
# -
# 1.
# 2.
# 3.
# | Tables   |      Price      |
# |----------|:-------------:|
# | col 1  |  1600 |
# | col 2  |    12   |
# | col 3  | 1 |
#
# <https://www.coursera.org/>
